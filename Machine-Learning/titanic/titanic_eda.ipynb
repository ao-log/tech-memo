# %% [markdown]
# # タイタニックデータの探索的データ解析

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('input/train.csv')
df_test = pd.read_csv('input/test.csv')

# %% [markdown]
# ## サマリ

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(df_train.columns)
print(df_test.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.describe(percentiles=[.1, .2, .3, .4, .5, .6, .7, .8, .9])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 10%      90.000000    0.000000    1.000000   14.000000    0.000000
# 20%     179.000000    0.000000    1.000000   19.000000    0.000000
# 30%     268.000000    0.000000    2.000000   22.000000    0.000000
# 40%     357.000000    0.000000    2.000000   25.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 60%     535.000000    0.000000    3.000000   31.800000    0.000000
# 70%     624.000000    1.000000    3.000000   36.000000    1.000000
# 80%     713.000000    1.000000    3.000000   41.000000    1.000000
# 90%     802.000000    1.000000    3.000000   50.000000    1.000000
# ...

# %%
df_train.describe(include = 'O')
# Out:
#                               Name   Sex  Ticket        Cabin Embarked
# count                          891   891     891          204      889
# unique                         891     2     681          147        3
# top     Fortune, Miss. Mabel Helen  male  347082  C23 C25 C27        S
# freq                             1   577       7            4      644

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## 中身の概要確認

# %%
#欠損値
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 各カラムの値の種類数
df_train.apply(lambda x: x.nunique())
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
from collections import Counter

# %%
# どのような値が格納されているか
pd.DataFrame(df_train.select_dtypes(include=object).
             apply(lambda x: Counter(x).most_common(10)))
# Out:
#                                                           0
# Name      [(Braund, Mr. Owen Harris, 1), (Cumings, Mrs. ...
# Sex                            [(male, 577), (female, 314)]
# Ticket    [(347082, 7), (1601, 7), (CA. 2343, 7), (31012...
# Cabin     [(nan, 687), (G6, 4), (C23 C25 C27, 4), (B96 B...
# Embarked            [(S, 644), (C, 168), (Q, 77), (nan, 2)]

# %% [markdown]
# ## カテゴリ変数化

# %%
df_train_map = df_train.copy()
df_train_map['Sex'] = df_train_map['Sex'].map({'male': 0, 'female': 1})
df_train_map['Embarked'] = df_train_map['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# %% [markdown]
# ## 特徴量の関連度

# %%
df_train_map.corr()['Survived'].sort_values(ascending=False).plot.bar()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df_train_map.corr(), annot=True, cmap='Blues')

# %%
df_train_map.corr().loc['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Sex            0.543351
# Fare           0.257307
# Embarked       0.108669
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
sns.pairplot(df_train[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']], hue='Survived')
# Out:
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %% [markdown]
# ## 各変数ごとに確認

# %%
df_train_pre = df_train.copy()

# %% [markdown]
# ### 生存者

# %%
sns.countplot(x='Survived', data=df_train)

# %%
columns = ['Sex', 'Pclass', 'SibSp', 'Parch', 'Embarked']

fig, axes = plt.subplots(len(columns), 1, figsize=(8, 20))
plt.subplots_adjust(hspace=0.3)

for column, ax in zip(columns, axes):
    sns.countplot(x='Survived', hue=column, data=df_train, ax=ax)
    ax.legend(loc='upper right')
    ax.set_title(column)

# %%
sns.countplot(x='Survived', hue='Sex', data=df_train)

# %%
sns.countplot(x='Survived', hue='Pclass', data=df_train)

# %%
sns.countplot(x='Survived', hue='SibSp', data=df_train)

# %%
sns.countplot(x='Survived', hue='Parch', data=df_train)

# %%
sns.countplot(x='Survived', hue='Embarked', data=df_train)

# %% [markdown]
# ### 性別

# %%
sns.countplot(x='Sex', hue='Survived', data=df_train)
plt.legend(['Death', 'Live'])

# %%
display(pd.crosstab(df_train['Sex'], df_train['Survived']))
display(pd.crosstab(df_train['Sex'], df_train['Survived'], normalize='index'))
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
df_train[['Survived', 'Sex']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
df_train.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df_train.pivot_table(values='Survived', index='Sex', columns='SibSp', aggfunc='sum')
# Out:
# SibSp     0   1   2  3  4  5  8
# Sex
# female  137  80  10  4  2  0  0
# male     73  32   3  0  1  0  0

# %%
df_train_pre['Sex'] = df_train_pre['Sex'].map({'male': 0, 'female': 1})

# %% [markdown]
# ### 客室クラス

# %%
sns.countplot(x='Pclass', hue='Survived', data=df_train)
plt.legend(['Death', 'Live'])

# %%
df_train[['Survived', 'Pclass']].groupby(['Pclass']).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# ### 年齢

# %%
sns.distplot(df_train['Age'].dropna(), kde=False, bins=30, label='All')
sns.distplot(df_train[df_train['Survived'] == 0].Age.dropna(), kde=False, bins=30, label='Death')
sns.distplot(df_train[df_train['Survived'] == 1].Age.dropna(), kde=False, bins=30, label='Live')
plt.legend()

# %%
df_train_pre['CategoricalAge'] = pd.cut(df_train_pre['Age'], 8)

# %%
display(pd.crosstab(df_train_pre['CategoricalAge'], df_train_pre['Survived']))
display(pd.crosstab(df_train_pre['CategoricalAge'], df_train_pre['Survived'], normalize='index'))
# Out:
# Survived            0   1
# CategoricalAge
# (0.34, 10.368]     26  38
# (10.368, 20.315]   71  44
# (20.315, 30.263]  146  84
# (30.263, 40.21]    86  69
# (40.21, 50.158]    53  33
# (50.158, 60.105]   25  17
# (60.105, 70.052]   13   4
# (70.052, 80.0]      4   1
# Survived                 0         1
# CategoricalAge
# (0.34, 10.368]    0.406250  0.593750
# (10.368, 20.315]  0.617391  0.382609
# (20.315, 30.263]  0.634783  0.365217
# (30.263, 40.21]   0.554839  0.445161
# (40.21, 50.158]   0.616279  0.383721
# (50.158, 60.105]  0.595238  0.404762
# (60.105, 70.052]  0.764706  0.235294
# (70.052, 80.0]    0.800000  0.200000

# %%
df_train['CategoricalAge'] = pd.cut(df_train['Age'], 12)
pd.crosstab(df_train['CategoricalAge'], df_train['Survived'], normalize='index').plot.bar(stacked=True)

# %%
df_train['CategoricalAge'] = pd.cut(df_train['Age'], 12)
pd.crosstab(df_train['CategoricalAge'], df_train['Survived']).plot.bar(stacked=True)

# %%
sns.heatmap(pd.crosstab(df_train_pre['CategoricalAge'], df_train_pre['Pclass'], normalize='index'), annot=True, cmap='Blues')

# %%
sns.boxplot(x='Pclass', y='Age', data=df_train)

# %%
sns.lmplot(x='Fare', y='Age', hue='Survived', data=df_train, fit_reg=False)

# %% [markdown]
# ### 兄弟または配偶者の数

# %%
sns.countplot(x='SibSp', data=df_train)

# %%
df_train_pre['SibSp_0_1_2over'] = [i if i<=1 else 2 for i in df_train_pre['SibSp']]
sns.countplot(x='SibSp_0_1_2over', hue='Survived', data=df_train_pre)
plt.legend(['Death', 'Live'])

# %% [markdown]
# ### 両親または子供の数

# %%
sns.countplot(x='Parch', data=df_train)

# %%
df_train_pre['Parch_0_1_2_3over'] = [i if i<=2 else 3 for i in df_train_pre['Parch']]
sns.countplot(x='Parch_0_1_2_3over', hue='Survived', data=df_train_pre)
plt.legend(['Death', 'Live'])

# %%
df_train_pre['FamilySize'] = df_train_pre['SibSp'] + df_train_pre['Parch'] +1

df_train_pre['IsAlone'] = 0
df_train_pre.loc[df_train_pre['FamilySize'] >= 2, 'IsAlone'] = 1

# %%
sns.countplot(x='IsAlone', hue='Survived', data=df_train_pre)
plt.legend(['Death', 'Live'])

# %% [markdown]
# ### 運賃

# %%
sns.distplot(df_train['Fare'].dropna(), kde=False, hist=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='Pclass', y='Fare', data=df_train)

# %%
df_train_pre['CategoricalFare'] = pd.qcut(df_train['Fare'], 4)

# %%
display(pd.crosstab(df_train_pre['CategoricalFare'], df_train_pre['Survived']))
display(pd.crosstab(df_train_pre['CategoricalFare'], df_train_pre['Survived'], normalize='index'))
# Out:
# Survived           0    1
# CategoricalFare
# (-0.001, 7.91]   179   44
# (7.91, 14.454]   156   68
# (14.454, 31.0]   121  101
# (31.0, 512.329]   93  129
# Survived                0         1
# CategoricalFare
# (-0.001, 7.91]   0.802691  0.197309
# (7.91, 14.454]   0.696429  0.303571
# (14.454, 31.0]   0.545045  0.454955
# (31.0, 512.329]  0.418919  0.581081

# %% [markdown]
# ### 出港地

# %%
df_train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
grid = sns.FacetGrid(df_train, row='Embarked', size=2.2, aspect=1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
grid.add_legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:720: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# ...

# %%
df_train_pre['Embarked'] = df_train_pre['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# %% [markdown]
# ### 相関関係

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_train_pre.drop(['SibSp_0_1_2over', 'Parch_0_1_2_3over'], axis=1).corr(), annot=True, cmap='Blues')

# %%
df_train_pre.corr().loc['Survived'].sort_values(ascending=False)
# Out:
# Survived             1.000000
# Sex                  0.543351
# Fare                 0.257307
# IsAlone              0.203367
# Embarked             0.108669
# Parch_0_1_2_3over    0.106532
# Parch                0.081629
# SibSp_0_1_2over      0.054203
# FamilySize           0.016639
# PassengerId         -0.005007
# SibSp               -0.035322
# Age                 -0.077221
# Pclass              -0.338481
# Name: Survived, dtype: float64
